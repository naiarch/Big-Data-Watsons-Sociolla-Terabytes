# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # **Load Data**

# %%
url = 'https://raw.githubusercontent.com/naiarch/UTS-Big-Data-Web-Scraping-Lazada/main/products_sociolla.csv'

df = pd.read_csv(url)
df.head()
# Out:
#   brand_name                  product_name  product_id  beauty_point_earned  \
# 0    796_3ce       MULTI EYE COLOR PALETTE       97802                  130
# 1    796_3ce               VELVET LIP TINT       97810                   50
# 2    796_3ce                     LIP COLOR       97822                   60
# 3    796_3ce  MINI MULTI EYE COLOR PALETTE       97833                   80
# 4    796_3ce                    FACE BLUSH       97801                   60
#
#                price_range price_by_combinations  \
# 0  Rp 555.000 - Rp 687.000                   NaN
# 1               Rp 264.000                   NaN
# 2               Rp 317.000                   NaN
# 3               Rp 423.000                   NaN
# 4               Rp 300.000                   NaN
#
#                                                  url  \
# 0  https://www.sociolla.com/eyeshadow/69460-phan-...
# 1  https://www.sociolla.com/lip-cream/69468-son-k...
# 2  https://www.sociolla.com/lip-matte/69480-son-t...
# 3  https://www.sociolla.com/eyeshadow/69491-phan-...
# 4  https://www.sociolla.com/blush/69459-phan-ma-h...
#
#                 active_date default_category               categories  \
# 0  2022-10-03T03:30:06.681Z        Eyeshadow  Makeup; Eyes; Eyeshadow
# 1  2022-10-03T03:02:40.340Z        Lip Cream  Makeup; Lips; Lip Cream
# 2  2023-05-30T09:49:15.158Z         Lipstick   Makeup; Lips; Lipstick
# 3  2022-10-03T03:27:01.334Z        Eyeshadow  Makeup; Eyes; Eyeshadow
# 4  2022-10-03T03:22:26.610Z            Blush      Makeup; Face; Blush
#
#                                     rating_types_str  average_rating  \
# 0  is_star_long_wear;is_star_packaging;is_star_pi...        4.920000
# 1  is_star_long_wear;is_star_packaging;is_star_pi...        4.576190
# 2  is_star_long_wear;is_star_packaging;is_star_pi...        0.000000
# 3  is_star_long_wear;is_star_packaging;is_star_pi...        4.883333
# 4  is_star_long_wear;is_star_packaging;is_star_pi...        4.858824
#
#    total_reviews                            average_rating_by_types  \
# 0              5  "star_long_wear": 5; "star_packaging": 4.8; "s...
# 1             42  "star_long_wear": 4.309523809523809; "star_pac...
# 2              0                                                NaN
# 3              6  "star_long_wear": 4.916666666666667; "star_pac...
# 4             13  "star_long_wear": 4.9411764705882355; "star_pa...
#
#    total_recommended_count  total_repurchase_maybe_count  \
# 0                        5                             0
# 1                       42                            10
# 2                        0                             0
# 3                       12                             1
# 4                       17                             2
#
#    total_repurchase_no_count  total_repurchase_yes_count  total_in_wishlist
# 0                          0                           5                717
# 1                          2                          30                682
# 2                          0                           0                173
# 3                          0                          11                257
# 4                          0                          15                387

# %%
df.tail()
# Out:
#            brand_name                  product_name  product_id  \
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned price_range price_by_combinations  \
# 7631                  130  Rp 659.000                   NaN
# 7632                   30  Rp 199.000                   NaN
# 7633                   50  Rp 289.000                   NaN
# 7634                   20  Rp 109.000                   NaN
# 7635                   50  Rp 289.000                   NaN
#
#                                                     url  \
# 7631  https://sociolla.com/fragrance/8088-ambre-noir...
# 7632  https://vn.sociolla.com/d-u-x/17239-soin-stimu...
# 7633  https://www.sociolla.com/hair-mask/14833-repai...
# 7634  https://www.sociolla.com/221-hand-and-foot-cre...
# 7635   https://vn.sociolla.com/kem-t-c/17224-color-mask
#
#                    active_date   default_category  \
# 7631                       NaN    Eau De Toilette
# 7632                       NaN        Conditioner
# 7633  2022-10-27T07:33:19.380Z          Hair Mask
# 7634                       NaN  Hand & Foot Cream
# 7635  2023-09-20T10:38:15.154Z          Hair Mask
#
#                                             categories  \
# 7631                 Shop By Departments; Home; UOBMon
# 7632                   Hair Care; Shampoo; Conditioner
# 7633              Hair Care; Hair Treatment; Hair Mask
# 7634  Shop By Departments; Home; 12.12 PRICE POINT 50%
# 7635              Hair Care; Hair Treatment; Hair Mask
#
#                                        rating_types_str  average_rating  \
# 7631  is_star_long_wear;is_star_packaging;is_star_va...        4.476190
# 7632  is_star_effectiveness;is_star_packaging;is_sta...        4.638889
# 7633  is_star_effectiveness;is_star_packaging;is_sta...        4.750000
# 7634  is_star_effectiveness;is_star_packaging;is_sta...        4.968750
# 7635  is_star_effectiveness;is_star_packaging;is_sta...        4.500000
#
#       total_reviews                            average_rating_by_types  \
# 7631              7  "star_long_wear": 4.285714285714286; "star_pac...
# 7632              9  "star_effectiveness": 4.444444444444445; "star...
# 7633              5  "star_effectiveness": 5; "star_packaging": 5; ...
# 7634              8  "star_effectiveness": 5; "star_packaging": 5; ...
# 7635              2  "star_effectiveness": 4.5; "star_packaging": 4...
#
#       total_recommended_count  total_repurchase_maybe_count  \
# 7631                        6                             1
# 7632                        7                             1
# 7633                        5                             1
# 7634                        8                             2
# 7635                        2                             1
#
#       total_repurchase_no_count  total_repurchase_yes_count  total_in_wishlist
# 7631                          2                           4                355
# 7632                          2                           6                122
# 7633                          0                           4                 58
# 7634                          0                           6                117
# 7635                          0                           1                 35

# %% [markdown]
# # **Informasi Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7636 entries, 0 to 7635
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   brand_name                    7636 non-null   object
#  1   product_name                  7636 non-null   object
#  2   product_id                    7636 non-null   int64
#  3   beauty_point_earned           7636 non-null   int64
#  4   price_range                   7636 non-null   object
#  5   price_by_combinations         4087 non-null   object
#  6   url                           7636 non-null   object
#  7   active_date                   5534 non-null   object
#  8   default_category              7636 non-null   object
#  9   categories                    7632 non-null   object
#  10  rating_types_str              7561 non-null   object
#  11  average_rating                7636 non-null   float64
#  12  total_reviews                 7636 non-null   int64
#  13  average_rating_by_types       5790 non-null   object
#  14  total_recommended_count       7636 non-null   int64
#  15  total_repurchase_maybe_count  7636 non-null   int64
#  16  total_repurchase_no_count     7636 non-null   int64
#  17  total_repurchase_yes_count    7636 non-null   int64
#  18  total_in_wishlist             7636 non-null   int64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# # **Cek Duplikasi Data**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Cek Missing Value**

# %%
df.isnull().sum()
# Out:
# brand_name                         0
# product_name                       0
# product_id                         0
# beauty_point_earned                0
# price_range                        0
# price_by_combinations           3549
# url                                0
# active_date                     2102
# default_category                   0
# categories                         4
# rating_types_str                  75
# average_rating                     0
# total_reviews                      0
# average_rating_by_types         1846
# total_recommended_count            0
# total_repurchase_maybe_count       0
# total_repurchase_no_count          0
# total_repurchase_yes_count         0
# total_in_wishlist                  0
# dtype: int64

# %% [markdown]
# # **Adjusting Column**

# %%
# @title drop kolom
df = df.drop(columns=['brand_name', 'product_id', 'price_by_combinations', 'beauty_point_earned', 'url', 'active_date', 'default_category', 'categories', 'rating_types_str', 'average_rating_by_types', 'total_recommended_count', 'total_in_wishlist'])
df
# Out:
#                       product_name              price_range  average_rating  \
# 0          MULTI EYE COLOR PALETTE  Rp 555.000 - Rp 687.000        4.920000
# 1                  VELVET LIP TINT               Rp 264.000        4.576190
# 2                        LIP COLOR               Rp 317.000        0.000000
# 3     MINI MULTI EYE COLOR PALETTE               Rp 423.000        4.883333
# 4                       FACE BLUSH               Rp 300.000        4.858824
# ...                            ...                      ...             ...
# 7631    Ambre Noir Eau De Toilette               Rp 659.000        4.476190
# 7632  Soin Stimulating Conditioner               Rp 199.000        4.638889
# 7633              Repair Hair Mask               Rp 289.000        4.750000
# 7634   Hand Cream Olive Petitgrain               Rp 109.000        4.968750
# 7635                    Color Mask               Rp 289.000        4.500000
#
#       total_reviews  total_repurchase_maybe_count  total_repurchase_no_count  \
# 0                 5                             0                          0
# 1                42                            10                          2
# 2                 0                             0                          0
# 3                 6                             1                          0
# 4                13                             2                          0
# ...             ...                           ...                        ...
# 7631              7                             1                          2
# 7632              9                             1                          2
# 7633              5                             1                          0
# 7634              8                             2                          0
# 7635              2                             1                          0
#
#       total_repurchase_yes_count
# 0                              5
# 1                             30
# 2                              0
# 3                             11
# 4                             15
# ...                          ...
# 7631                           4
# 7632                           6
# 7633                           4
# 7634                           6
# 7635                           1
#
# [7636 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7636 entries, 0 to 7635
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   product_name                  7636 non-null   object
#  1   price_range                   7636 non-null   object
#  2   average_rating                7636 non-null   float64
#  3   total_reviews                 7636 non-null   int64
#  4   total_repurchase_maybe_count  7636 non-null   int64
#  5   total_repurchase_no_count     7636 non-null   int64
#  6   total_repurchase_yes_count    7636 non-null   int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 417.7+ KB

# %%
# @title kolom harga
def clean_and_average_price(price_str):
    cleaned = re.sub(r'[^\d\-]', '', str(price_str))
    if not cleaned:
        return 0.0
    if '-' in cleaned:
        prices = cleaned.split('-')
        valid_prices = [float(p) for p in prices if p]
        return sum(valid_prices) / len(valid_prices) if valid_prices else 0.0
    else:
        return float(cleaned)

df['harga_original'] = df['price_range'].apply(clean_and_average_price)
df = df.drop(columns=['price_range'])
df
# Out:
#                       product_name  average_rating  total_reviews  \
# 0          MULTI EYE COLOR PALETTE        4.920000              5
# 1                  VELVET LIP TINT        4.576190             42
# 2                        LIP COLOR        0.000000              0
# 3     MINI MULTI EYE COLOR PALETTE        4.883333              6
# 4                       FACE BLUSH        4.858824             13
# ...                            ...             ...            ...
# 7631    Ambre Noir Eau De Toilette        4.476190              7
# 7632  Soin Stimulating Conditioner        4.638889              9
# 7633              Repair Hair Mask        4.750000              5
# 7634   Hand Cream Olive Petitgrain        4.968750              8
# 7635                    Color Mask        4.500000              2
#
#       total_repurchase_maybe_count  total_repurchase_no_count  \
# 0                                0                          0
# 1                               10                          2
# 2                                0                          0
# 3                                1                          0
# 4                                2                          0
# ...                            ...                        ...
# 7631                             1                          2
# 7632                             1                          2
# 7633                             1                          0
# 7634                             2                          0
# 7635                             1                          0
#
#       total_repurchase_yes_count  harga_original
# 0                              5        621000.0
# 1                             30        264000.0
# 2                              0        317000.0
# 3                             11        423000.0
# 4                             15        300000.0
# ...                          ...             ...
# 7631                           4        659000.0
# 7632                           6        199000.0
# 7633                           4        289000.0
# 7634                           6        109000.0
# 7635                           1        289000.0
#
# [7636 rows x 7 columns]

# %%
# @title kolom jumlah_terjual
df['jumlah_terjual'] = (
    df['total_repurchase_maybe_count'] +
    df['total_repurchase_no_count'] +
    df['total_repurchase_yes_count']
)

kolom_yang_didrop = ['total_repurchase_maybe_count', 'total_repurchase_no_count',
                     'total_repurchase_yes_count']
df = df.drop(columns=kolom_yang_didrop)
df
# Out:
#                       product_name  average_rating  total_reviews  \
# 0          MULTI EYE COLOR PALETTE        4.920000              5
# 1                  VELVET LIP TINT        4.576190             42
# 2                        LIP COLOR        0.000000              0
# 3     MINI MULTI EYE COLOR PALETTE        4.883333              6
# 4                       FACE BLUSH        4.858824             13
# ...                            ...             ...            ...
# 7631    Ambre Noir Eau De Toilette        4.476190              7
# 7632  Soin Stimulating Conditioner        4.638889              9
# 7633              Repair Hair Mask        4.750000              5
# 7634   Hand Cream Olive Petitgrain        4.968750              8
# 7635                    Color Mask        4.500000              2
#
#       harga_original  jumlah_terjual
# 0           621000.0               5
# 1           264000.0              42
# 2           317000.0               0
# 3           423000.0              12
# 4           300000.0              17
# ...              ...             ...
# 7631        659000.0               7
# 7632        199000.0               9
# 7633        289000.0               5
# 7634        109000.0               8
# 7635        289000.0               2
#
# [7636 rows x 5 columns]

# %%
# @title fixed column
# membuat kolom baru untuk menyesuaikan dengan dataset watsons
df['toko'] = 'Sociolla'
df['harga'] = 0.0
df['diskon'] = 0.0

# mengubah nama kolom untuk menyesuaikan dengan dataset watsons
kolom_baru = {
    'product_name': 'nama_produk',
    'average_rating': 'rating',
    'total_reviews': 'jumlah_review',
}
df = df.rename(columns=kolom_baru)

# memperbaiki kolom rating (rating 0 menjadi NaN)
df['rating'] = df['rating'].replace(0.0, np.nan)

# mengatur ulang urutan kolom
urutan_kolom = [
    'toko',
    'nama_produk',
    'harga',
    'harga_original',
    'diskon',
    'rating',
    'jumlah_review',
    'jumlah_terjual'
]
df = df[urutan_kolom]
df
# Out:
#           toko                   nama_produk  harga  harga_original  diskon  \
# 0     Sociolla       MULTI EYE COLOR PALETTE    0.0        621000.0     0.0
# 1     Sociolla               VELVET LIP TINT    0.0        264000.0     0.0
# 2     Sociolla                     LIP COLOR    0.0        317000.0     0.0
# 3     Sociolla  MINI MULTI EYE COLOR PALETTE    0.0        423000.0     0.0
# 4     Sociolla                    FACE BLUSH    0.0        300000.0     0.0
# ...        ...                           ...    ...             ...     ...
# 7631  Sociolla    Ambre Noir Eau De Toilette    0.0        659000.0     0.0
# 7632  Sociolla  Soin Stimulating Conditioner    0.0        199000.0     0.0
# 7633  Sociolla              Repair Hair Mask    0.0        289000.0     0.0
# 7634  Sociolla   Hand Cream Olive Petitgrain    0.0        109000.0     0.0
# 7635  Sociolla                    Color Mask    0.0        289000.0     0.0
#
#         rating  jumlah_review  jumlah_terjual
# 0     4.920000              5               5
# 1     4.576190             42              42
# 2          NaN              0               0
# 3     4.883333              6              12
# 4     4.858824             13              17
# ...        ...            ...             ...
# 7631  4.476190              7               7
# 7632  4.638889              9               9
# 7633  4.750000              5               5
# 7634  4.968750              8               8
# 7635  4.500000              2               2
#
# [7636 rows x 8 columns]

# %% [markdown]
# # **Menyimpan Dataset Sociolla**

# %%
df.to_csv('products_sociolla_clean.csv', index=False)
print("Dataset berhasil disimpan dengan nama 'products_sociolla_clean.csv'!")
# Out:
# Dataset berhasil disimpan dengan nama 'products_sociolla_clean.csv'!
